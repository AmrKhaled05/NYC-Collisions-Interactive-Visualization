# %%
import pandas as pd
import numpy as np
import pyarrow

# %%
# Adding engine='pyarrow' usually solves memory issues instantly
df = pd.read_csv('integrated_crashes_person.csv', engine='pyarrow')

# %%
# 'index=False' prevents saving the row numbers as a separate column
df.to_parquet('Final_Data.parquet', index=False)

# %%
df = pd.read_parquet(path='Final_Data.parquet', engine='pyarrow')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5257484 entries, 0 to 5257483
# Data columns (total 39 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   BOROUGH                        object
#  1   ZIP CODE                       object
#  2   LATITUDE                       float64
#  3   LONGITUDE                      float64
#  4   LOCATION                       object
#  5   ON STREET NAME                 object
#  6   CROSS STREET NAME              object
#  7   OFF STREET NAME                object
#  8   NUMBER OF PERSONS INJURED      float64
#  9   NUMBER OF PERSONS KILLED       float64
#  10  NUMBER OF PEDESTRIANS INJURED  int64
#  11  NUMBER OF PEDESTRIANS KILLED   int64
#  12  NUMBER OF CYCLIST INJURED      int64
#  13  NUMBER OF CYCLIST KILLED       int64
#  14  NUMBER OF MOTORIST INJURED     int64
#  15  NUMBER OF MOTORIST KILLED      int64
#  16  CONTRIBUTING FACTOR VEHICLE 1  object
#  17  CONTRIBUTING FACTOR VEHICLE 2  object
#  18  CONTRIBUTING FACTOR VEHICLE 3  object
#  19  CONTRIBUTING FACTOR VEHICLE 4  object
#  20  CONTRIBUTING FACTOR VEHICLE 5  object
#  21  VEHICLE TYPE CODE 1            object
#  22  VEHICLE TYPE CODE 2            object
#  23  VEHICLE TYPE CODE 3            object
#  24  VEHICLE TYPE CODE 4            object
#  25  VEHICLE TYPE CODE 5            object
#  26  CRASH DATETIME                 datetime64[ms]
#  27  PERSON_TYPE                    object
#  28  PERSON_INJURY                  object
#  29  PERSON_SEX                     object
#  30  PED_ROLE                       object
#  31  PERSON_AGE                     float64
#  32  EJECTION                       object
#  33  EMOTIONAL_STATUS               object
#  34  POSITION_IN_VEHICLE            object
#  35  BODILY_INJURY                  object
#  36  COMPLAINT                      object
#  37  SAFETY_EQUIPMENT               object
#  38  CONTRIBUTING_FACTOR            object
# dtypes: datetime64[ms](1), float64(5), int64(6), object(27)
# memory usage: 1.5+ GB

# %%
df.nunique()
# Out:
# BOROUGH                               6
# ZIP CODE                            235
# LATITUDE                          82931
# LONGITUDE                         53578
# LOCATION                         361025
# ON STREET NAME                   246835
# CROSS STREET NAME                 16593
# OFF STREET NAME                  231634
# NUMBER OF PERSONS INJURED            30
# NUMBER OF PERSONS KILLED              7
# NUMBER OF PEDESTRIANS INJURED        14
# NUMBER OF PEDESTRIANS KILLED          6
# NUMBER OF CYCLIST INJURED             5
# NUMBER OF CYCLIST KILLED              3
# NUMBER OF MOTORIST INJURED           29
# NUMBER OF MOTORIST KILLED             6
# CONTRIBUTING FACTOR VEHICLE 1        18
# CONTRIBUTING FACTOR VEHICLE 2        18
# CONTRIBUTING FACTOR VEHICLE 3        16
# CONTRIBUTING FACTOR VEHICLE 4        13
# CONTRIBUTING FACTOR VEHICLE 5        12
# VEHICLE TYPE CODE 1                1708
# VEHICLE TYPE CODE 2                1910
# VEHICLE TYPE CODE 3                 276
# VEHICLE TYPE CODE 4                 105
# VEHICLE TYPE CODE 5                  72
# CRASH DATETIME                   905455
# PERSON_TYPE                           4
# PERSON_INJURY                         3
# PERSON_SEX                            3
# PED_ROLE                             11
# PERSON_AGE                           91
# EJECTION                              6
# EMOTIONAL_STATUS                      8
# POSITION_IN_VEHICLE                  11
# BODILY_INJURY                        14
# COMPLAINT                            21
# SAFETY_EQUIPMENT                     10
# CONTRIBUTING_FACTOR                  47
# dtype: int64

# %%
unspecified_counts = (df == 'Unspecified').sum()

# %%
print(unspecified_counts[unspecified_counts > 0])
# Out:
# CONTRIBUTING FACTOR VEHICLE 1    1100742
# CONTRIBUTING FACTOR VEHICLE 2    3789164
# CONTRIBUTING FACTOR VEHICLE 3     583970
# CONTRIBUTING FACTOR VEHICLE 4     170687
# CONTRIBUTING FACTOR VEHICLE 5      57070
# CONTRIBUTING_FACTOR              5228118
# dtype: int64

# %%
# Replace exact matches of 'Unspecified' with 'u' everywhere
df = df.replace('Unspecified', 'u')

# %%
# Data Type Optimizations
optimized_dtypes = {
    # --- Ultra-Light Categories (<32,768 uniques) ---
    'BOROUGH': 'category',
    'ZIP CODE': 'category',
    'CROSS STREET NAME': 'category',
    'CONTRIBUTING FACTOR VEHICLE 1': 'category',
    'CONTRIBUTING FACTOR VEHICLE 2': 'category',
    'CONTRIBUTING FACTOR VEHICLE 3': 'category',
    'CONTRIBUTING FACTOR VEHICLE 4': 'category',
    'CONTRIBUTING FACTOR VEHICLE 5': 'category',
    'VEHICLE TYPE CODE 1': 'category',
    'VEHICLE TYPE CODE 2': 'category',
    'VEHICLE TYPE CODE 3': 'category',
    'VEHICLE TYPE CODE 4': 'category',
    'VEHICLE TYPE CODE 5': 'category',
    'PERSON_TYPE': 'category',
    'PERSON_INJURY': 'category',
    'PERSON_SEX': 'category',
    'PED_ROLE': 'category',
    'EJECTION': 'category',
    'EMOTIONAL_STATUS': 'category',
    'POSITION_IN_VEHICLE': 'category',
    'BODILY_INJURY': 'category',
    'COMPLAINT': 'category',
    'SAFETY_EQUIPMENT': 'category',
    'CONTRIBUTING_FACTOR': 'category',

    # --- Numeric Optimizations ---
    'LATITUDE': 'float32',
    'LONGITUDE': 'float32',
    'NUMBER OF PERSONS INJURED': 'UInt8',
    'NUMBER OF PERSONS KILLED': 'UInt8',
    'NUMBER OF PEDESTRIANS INJURED': 'UInt8',
    'NUMBER OF PEDESTRIANS KILLED': 'UInt8',
    'NUMBER OF CYCLIST INJURED': 'UInt8',
    'NUMBER OF CYCLIST KILLED': 'UInt8',
    'NUMBER OF MOTORIST INJURED': 'UInt8',
    'NUMBER OF MOTORIST KILLED': 'UInt8',
    'PERSON_AGE': 'UInt8',

    # --- Datetime Optimization ---
    'CRASH DATETIME': 'datetime64[ns]'
}

# Apply all at once
df = df.astype(optimized_dtypes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5257484 entries, 0 to 5257483
# Data columns (total 39 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   BOROUGH                        category
#  1   ZIP CODE                       category
#  2   LATITUDE                       float32
#  3   LONGITUDE                      float32
#  4   LOCATION                       object
#  5   ON STREET NAME                 object
#  6   CROSS STREET NAME              category
#  7   OFF STREET NAME                object
#  8   NUMBER OF PERSONS INJURED      UInt8
#  9   NUMBER OF PERSONS KILLED       UInt8
#  10  NUMBER OF PEDESTRIANS INJURED  UInt8
#  11  NUMBER OF PEDESTRIANS KILLED   UInt8
#  12  NUMBER OF CYCLIST INJURED      UInt8
#  13  NUMBER OF CYCLIST KILLED       UInt8
#  14  NUMBER OF MOTORIST INJURED     UInt8
#  15  NUMBER OF MOTORIST KILLED      UInt8
#  16  CONTRIBUTING FACTOR VEHICLE 1  category
#  17  CONTRIBUTING FACTOR VEHICLE 2  category
#  18  CONTRIBUTING FACTOR VEHICLE 3  category
#  19  CONTRIBUTING FACTOR VEHICLE 4  category
#  20  CONTRIBUTING FACTOR VEHICLE 5  category
#  21  VEHICLE TYPE CODE 1            category
#  22  VEHICLE TYPE CODE 2            category
#  23  VEHICLE TYPE CODE 3            category
#  24  VEHICLE TYPE CODE 4            category
#  25  VEHICLE TYPE CODE 5            category
#  26  CRASH DATETIME                 datetime64[ns]
#  27  PERSON_TYPE                    category
#  28  PERSON_INJURY                  category
#  29  PERSON_SEX                     category
#  30  PED_ROLE                       category
#  31  PERSON_AGE                     UInt8
#  32  EJECTION                       category
#  33  EMOTIONAL_STATUS               category
#  34  POSITION_IN_VEHICLE            category
#  35  BODILY_INJURY                  category
#  36  COMPLAINT                      category
#  37  SAFETY_EQUIPMENT               category
#  38  CONTRIBUTING_FACTOR            category
# dtypes: UInt8(9), category(24), datetime64[ns](1), float32(2), object(3)
# memory usage: 437.0+ MB

# %%
df.head()
# Out:
#     BOROUGH ZIP CODE   LATITUDE  LONGITUDE                     LOCATION  \
# 0  BROOKLYN    11230  40.621792 -73.970024       (40.62179, -73.970024)
# 1  BROOKLYN    11230  40.621792 -73.970024       (40.62179, -73.970024)
# 2  BROOKLYN    11208  40.667202 -73.866501        (40.667202, -73.8665)
# 3  BROOKLYN    11208  40.667202 -73.866501        (40.667202, -73.8665)
# 4  BROOKLYN    11233  40.683304 -73.917274      (40.683304, -73.917274)
#
#             ON STREET NAME CROSS STREET NAME          OFF STREET NAME  \
# 0            OCEAN PARKWAY          AVENUE K            No Off Street
# 1            OCEAN PARKWAY          AVENUE K            No Off Street
# 2  1211      LORING AVENUE   No Cross Street  1211      LORING AVENUE
# 3  1211      LORING AVENUE   No Cross Street  1211      LORING AVENUE
# 4          SARATOGA AVENUE    DECATUR STREET            No Off Street
#
#    NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  ...  PERSON_SEX  \
# 0                          1                         0  ...           F
# 1                          1                         0  ...           M
# 2                          0                         0  ...           F
# 3                          0                         0  ...           F
# 4                          0                         0  ...           M
#
#      PED_ROLE  PERSON_AGE     EJECTION  EMOTIONAL_STATUS  \
# 0      Driver          63  Not Ejected    Does Not Apply
# 1      Driver          26      Ejected         Conscious
# 2      Driver          28  Not Ejected    Does Not Apply
# 3  Registrant          28  Not Ejected    Does Not Apply
# 4  Pedestrian          46  Not Ejected    Does Not Apply
#
#                                  POSITION_IN_VEHICLE        BODILY_INJURY  \
# 0                                             Driver       Does Not Apply
# 1                                             Driver  Knee-Lower Leg Foot
# 2                                            Unknown       Does Not Apply
# 3                                             Driver       Does Not Apply
# 4  Front passenger, if two or more persons, inclu...       Does Not Apply
#
#                      COMPLAINT SAFETY_EQUIPMENT CONTRIBUTING_FACTOR
# 0               Does Not Apply        Seat Belt                   u
# 1  Complaint of Pain or Nausea     No Equipment                   u
# 2               Does Not Apply     No Equipment                   u
# 3               Does Not Apply     No Equipment                   u
# 4               Does Not Apply     No Equipment                   u
#
# [5 rows x 39 columns]

# %%
df.nunique()
# Out:
# BOROUGH                               6
# ZIP CODE                            235
# LATITUDE                          82931
# LONGITUDE                         53578
# LOCATION                         361025
# ON STREET NAME                   246835
# CROSS STREET NAME                 16593
# OFF STREET NAME                  231634
# NUMBER OF PERSONS INJURED            30
# NUMBER OF PERSONS KILLED              7
# NUMBER OF PEDESTRIANS INJURED        14
# NUMBER OF PEDESTRIANS KILLED          6
# NUMBER OF CYCLIST INJURED             5
# NUMBER OF CYCLIST KILLED              3
# NUMBER OF MOTORIST INJURED           29
# NUMBER OF MOTORIST KILLED             6
# CONTRIBUTING FACTOR VEHICLE 1        18
# CONTRIBUTING FACTOR VEHICLE 2        18
# CONTRIBUTING FACTOR VEHICLE 3        16
# CONTRIBUTING FACTOR VEHICLE 4        13
# CONTRIBUTING FACTOR VEHICLE 5        12
# VEHICLE TYPE CODE 1                1708
# VEHICLE TYPE CODE 2                1910
# VEHICLE TYPE CODE 3                 276
# VEHICLE TYPE CODE 4                 105
# VEHICLE TYPE CODE 5                  72
# CRASH DATETIME                   905455
# PERSON_TYPE                           4
# PERSON_INJURY                         3
# PERSON_SEX                            3
# PED_ROLE                             11
# PERSON_AGE                           91
# EJECTION                              6
# EMOTIONAL_STATUS                      8
# POSITION_IN_VEHICLE                  11
# BODILY_INJURY                        14
# COMPLAINT                            21
# SAFETY_EQUIPMENT                     10
# CONTRIBUTING_FACTOR                  47
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5257484 entries, 0 to 5257483
# Data columns (total 39 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   BOROUGH                        category
#  1   ZIP CODE                       category
#  2   LATITUDE                       float32
#  3   LONGITUDE                      float32
#  4   LOCATION                       object
#  5   ON STREET NAME                 object
#  6   CROSS STREET NAME              category
#  7   OFF STREET NAME                object
#  8   NUMBER OF PERSONS INJURED      UInt8
#  9   NUMBER OF PERSONS KILLED       UInt8
#  10  NUMBER OF PEDESTRIANS INJURED  UInt8
#  11  NUMBER OF PEDESTRIANS KILLED   UInt8
#  12  NUMBER OF CYCLIST INJURED      UInt8
#  13  NUMBER OF CYCLIST KILLED       UInt8
#  14  NUMBER OF MOTORIST INJURED     UInt8
#  15  NUMBER OF MOTORIST KILLED      UInt8
#  16  CONTRIBUTING FACTOR VEHICLE 1  category
#  17  CONTRIBUTING FACTOR VEHICLE 2  category
#  18  CONTRIBUTING FACTOR VEHICLE 3  category
#  19  CONTRIBUTING FACTOR VEHICLE 4  category
#  20  CONTRIBUTING FACTOR VEHICLE 5  category
#  21  VEHICLE TYPE CODE 1            category
#  22  VEHICLE TYPE CODE 2            category
#  23  VEHICLE TYPE CODE 3            category
#  24  VEHICLE TYPE CODE 4            category
#  25  VEHICLE TYPE CODE 5            category
#  26  CRASH DATETIME                 datetime64[ns]
#  27  PERSON_TYPE                    category
#  28  PERSON_INJURY                  category
#  29  PERSON_SEX                     category
#  30  PED_ROLE                       category
#  31  PERSON_AGE                     UInt8
#  32  EJECTION                       category
#  33  EMOTIONAL_STATUS               category
#  34  POSITION_IN_VEHICLE            category
#  35  BODILY_INJURY                  category
#  36  COMPLAINT                      category
#  37  SAFETY_EQUIPMENT               category
#  38  CONTRIBUTING_FACTOR            category
# dtypes: UInt8(9), category(24), datetime64[ns](1), float32(2), object(3)
# memory usage: 437.0+ MB

# %%
for col in ['ON STREET NAME', 'OFF STREET NAME']:
    df[col] = df[col].astype('category')

# We use memory_usage='deep' to see the true size including text strings
print("Real Memory Usage:")
df.info(memory_usage='deep')
# Out:
# Real Memory Usage:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5257484 entries, 0 to 5257483
# Data columns (total 39 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   BOROUGH                        category
#  1   ZIP CODE                       category
#  2   LATITUDE                       float32
#  3   LONGITUDE                      float32
#  4   LOCATION                       object
#  5   ON STREET NAME                 category
#  6   CROSS STREET NAME              category
#  7   OFF STREET NAME                category
#  8   NUMBER OF PERSONS INJURED      UInt8
#  9   NUMBER OF PERSONS KILLED       UInt8
#  10  NUMBER OF PEDESTRIANS INJURED  UInt8
#  11  NUMBER OF PEDESTRIANS KILLED   UInt8
#  12  NUMBER OF CYCLIST INJURED      UInt8
#  13  NUMBER OF CYCLIST KILLED       UInt8
#  14  NUMBER OF MOTORIST INJURED     UInt8
#  15  NUMBER OF MOTORIST KILLED      UInt8
#  16  CONTRIBUTING FACTOR VEHICLE 1  category
#  17  CONTRIBUTING FACTOR VEHICLE 2  category
#  18  CONTRIBUTING FACTOR VEHICLE 3  category
#  19  CONTRIBUTING FACTOR VEHICLE 4  category
#  20  CONTRIBUTING FACTOR VEHICLE 5  category
#  21  VEHICLE TYPE CODE 1            category
#  22  VEHICLE TYPE CODE 2            category
#  23  VEHICLE TYPE CODE 3            category
#  24  VEHICLE TYPE CODE 4            category
#  25  VEHICLE TYPE CODE 5            category
#  26  CRASH DATETIME                 datetime64[ns]
#  27  PERSON_TYPE                    category
#  28  PERSON_INJURY                  category
#  29  PERSON_SEX                     category
#  30  PED_ROLE                       category
#  31  PERSON_AGE                     UInt8
#  32  EJECTION                       category
#  33  EMOTIONAL_STATUS               category
#  34  POSITION_IN_VEHICLE            category
#  35  BODILY_INJURY                  category
#  36  COMPLAINT                      category
#  37  SAFETY_EQUIPMENT               category
#  38  CONTRIBUTING_FACTOR            category
# dtypes: UInt8(9), category(26), datetime64[ns](1), float32(2), object(1)
# memory usage: 771.9 MB

# %%
df.drop('LOCATION', axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5257484 entries, 0 to 5257483
# Data columns (total 38 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   BOROUGH                        category
#  1   ZIP CODE                       category
#  2   LATITUDE                       float32
#  3   LONGITUDE                      float32
#  4   ON STREET NAME                 category
#  5   CROSS STREET NAME              category
#  6   OFF STREET NAME                category
#  7   NUMBER OF PERSONS INJURED      UInt8
#  8   NUMBER OF PERSONS KILLED       UInt8
#  9   NUMBER OF PEDESTRIANS INJURED  UInt8
#  10  NUMBER OF PEDESTRIANS KILLED   UInt8
#  11  NUMBER OF CYCLIST INJURED      UInt8
#  12  NUMBER OF CYCLIST KILLED       UInt8
#  13  NUMBER OF MOTORIST INJURED     UInt8
#  14  NUMBER OF MOTORIST KILLED      UInt8
#  15  CONTRIBUTING FACTOR VEHICLE 1  category
#  16  CONTRIBUTING FACTOR VEHICLE 2  category
#  17  CONTRIBUTING FACTOR VEHICLE 3  category
#  18  CONTRIBUTING FACTOR VEHICLE 4  category
#  19  CONTRIBUTING FACTOR VEHICLE 5  category
#  20  VEHICLE TYPE CODE 1            category
#  21  VEHICLE TYPE CODE 2            category
#  22  VEHICLE TYPE CODE 3            category
#  23  VEHICLE TYPE CODE 4            category
#  24  VEHICLE TYPE CODE 5            category
#  25  CRASH DATETIME                 datetime64[ns]
#  26  PERSON_TYPE                    category
#  27  PERSON_INJURY                  category
#  28  PERSON_SEX                     category
#  29  PED_ROLE                       category
#  30  PERSON_AGE                     UInt8
#  31  EJECTION                       category
#  32  EMOTIONAL_STATUS               category
#  33  POSITION_IN_VEHICLE            category
#  34  BODILY_INJURY                  category
#  35  COMPLAINT                      category
#  36  SAFETY_EQUIPMENT               category
#  37  CONTRIBUTING_FACTOR            category
# dtypes: UInt8(9), category(26), datetime64[ns](1), float32(2)
# memory usage: 376.6 MB

# %%
df.drop(columns='OFF STREET NAME', inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5257484 entries, 0 to 5257483
# Data columns (total 37 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   BOROUGH                        category
#  1   ZIP CODE                       category
#  2   LATITUDE                       float32
#  3   LONGITUDE                      float32
#  4   ON STREET NAME                 category
#  5   CROSS STREET NAME              category
#  6   NUMBER OF PERSONS INJURED      UInt8
#  7   NUMBER OF PERSONS KILLED       UInt8
#  8   NUMBER OF PEDESTRIANS INJURED  UInt8
#  9   NUMBER OF PEDESTRIANS KILLED   UInt8
#  10  NUMBER OF CYCLIST INJURED      UInt8
#  11  NUMBER OF CYCLIST KILLED       UInt8
#  12  NUMBER OF MOTORIST INJURED     UInt8
#  13  NUMBER OF MOTORIST KILLED      UInt8
#  14  CONTRIBUTING FACTOR VEHICLE 1  category
#  15  CONTRIBUTING FACTOR VEHICLE 2  category
#  16  CONTRIBUTING FACTOR VEHICLE 3  category
#  17  CONTRIBUTING FACTOR VEHICLE 4  category
#  18  CONTRIBUTING FACTOR VEHICLE 5  category
#  19  VEHICLE TYPE CODE 1            category
#  20  VEHICLE TYPE CODE 2            category
#  21  VEHICLE TYPE CODE 3            category
#  22  VEHICLE TYPE CODE 4            category
#  23  VEHICLE TYPE CODE 5            category
#  24  CRASH DATETIME                 datetime64[ns]
#  25  PERSON_TYPE                    category
#  26  PERSON_INJURY                  category
#  27  PERSON_SEX                     category
#  28  PED_ROLE                       category
#  29  PERSON_AGE                     UInt8
#  30  EJECTION                       category
#  31  EMOTIONAL_STATUS               category
#  32  POSITION_IN_VEHICLE            category
#  33  BODILY_INJURY                  category
#  34  COMPLAINT                      category
#  35  SAFETY_EQUIPMENT               category
#  36  CONTRIBUTING_FACTOR            category
# dtypes: UInt8(9), category(25), datetime64[ns](1), float32(2)
# memory usage: 346.7 MB

# %%
df.to_parquet('Final_Data.parquet', index=False)

# %%
# Create a sample dataset for deployment testing
sample_size = 10000  # Adjust size as needed
df_sample = df.sample(n=sample_size, random_state=42)

print(f"Sample dataset created: {df_sample.shape}")
print(f"Memory usage: {df_sample.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

# Save sample as parquet for testing
df_sample.to_parquet('Sample_Data.parquet', index=False)
print("✅ Sample saved as 'Sample_Data.parquet'")
